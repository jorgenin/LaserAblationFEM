# %% [markdown]
# Source for initial: https://notebook.community/geo-fluid-dynamics/phaseflow-fenics/tutorials/FEniCS/03-ConvectionCoupledMelting-MixedElement-AMR
# geo-fluid-dynamics/phaseflow-fenics

# %% [markdown]
# |Nomenclature||
# |------------|-|
# |$\mathbf{x}$| point in the spatial domain|
# |$t$| time |
# |$p = p(\mathbf{x},t)$| pressure field |
# |$\mathbf{u} = \mathbf{u}(\mathbf{x},t)$| velocity vector field |
# |$T = T(\mathbf{x},t)$| temperature field |
# |$\phi$ | solid volume fraction |
# |$()_t = \frac{\partial}{\partial t}()$| time derivative |
# |$T_r$| central temperature of the regularization |
# |$r$| smoothing parameter of the regularization |
# |$\mu$| constant dynamic viscosity of the fluid|
# |$\mathbf{f}_B(T)$| temperature-dependent buoyancy force|
# |$\mathrm{Pr}$ | Prandtl number|
# |$\mathrm{Ra}$ | Rayleigh number|
# |$\mathrm{Ste}$| Stefan number|
# |$\Omega$| spatial domain |
# |$\mathbf{w} = \begin{pmatrix} p \\ \mathbf{u} \\ T \end{pmatrix}$| system solution|
# |$\mathbf{W}$| mixed finite element function space |
# |$\boldsymbol{\psi} = \begin{pmatrix} \psi_p \\ \boldsymbol{\psi}_u \\ \psi_T \end{pmatrix} $| mixed finite element basis functions|
# |$\gamma$| penalty method stabilization parameter|
# |$T_h$| hot boundary temperature |
# |$T_c$| cold boundary temperature |
# |$\Delta t$| time step size |
# |$\Omega_h$| discrete spatial domain, i.e. the mesh |
# |$M$| goal functional |
# |$\epsilon_M$| error tolerance for goal-oriented AMR |

# %% [markdown]
# ## Governing equations

# %% [markdown]
# To model convection-coupled melting, we employ the system composed of the unsteady incompressible Navier-Stokes-Boussinesq equations and a enthalpy convection-diffusion equation, scaled for unit Reynolds Number as explained in [5], as
#
# $$\begin{aligned}  \nabla \cdot \mathbf{u} &= 0  \\
#     \mathbf{u}_t + \left( \mathbf{u}\cdot\nabla\right)\mathbf{u} + \nabla p - 2\nabla \cdot \left(\mu(\phi)\mathbf{D}(\mathbf{u})\right) + \mathbf{f}_B(T) &=0  \\
#     T_t + \mathbf{u}\cdot\nabla T - \frac{1}{\mathrm{Pr}}\Delta T - \frac{1}{\mathrm{Ste}}\phi_t &=0 \end{aligned}$$
#
# where  $\mathbf{D}(\mathbf{u}) = \mathrm{sym}(\mathbf{u}) = \frac{1}{2}\left(\nabla \mathbf{u} +  \left( \nabla \mathbf{u} \right)^{\mathrm{T}} \right)$ is the Newtonian fluid's rate of strain tensor and the regularized semi-phase-field (representing the solid volume fraction) is
#
# $$\begin{aligned} \phi(T) = \frac{1}{2}\left(1 + \tanh{\frac{T_r - T}{r}} \right) \end{aligned}$$

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pyvista
from mpi4py import MPI
from petsc4py import PETSc

from dolfinx.fem import (Constant, dirichletbc, Function, FunctionSpace, assemble_scalar,
                         form, locate_dofs_geometrical, locate_dofs_topological, Expression )
from dolfinx.fem.petsc import LinearProblem
from dolfinx.io import XDMFFile
from dolfinx.plot import create_vtk_mesh

from dolfinx import mesh, fem, log

import dolfinx.nls.petsc

from ufl import (SpatialCoordinate, TestFunction, TrialFunction,
                 dx, grad, inner)

from ufl import (FacetNormal, FiniteElement, Identity,TestFunction, TrialFunction, VectorElement,
div, dot, ds, dx, inner, lhs, nabla_grad, rhs, sym, derivative, tanh)

import ufl

# %% [markdown]
# ## Initial mesh

# %% [markdown]
# Define a coarse mesh on the unit square and refine it near the hot wall where there will be an initial layer of melt.

# %%
N=100

domain = mesh.create_unit_square(MPI.COMM_WORLD,N, N,cell_type=mesh.CellType.triangle)

#Left hand side wall
def HotWall(x):
    return np.logical_and(np.logical_and(np.isclose(x[1], 1) , x[0]>0.2), x[0]<0.8)

initial_hot_wall_refinement_cycles = 0

for cycle in range(initial_hot_wall_refinement_cycles):

    #Facets on the hot wall
    hot_wall = mesh.locate_entities_boundary(domain,domain.topology.dim-1,  HotWall) 

    domain = mesh.refine(domain, hot_wall, redistribute=False)

# %% [markdown]
# Visualize the mesh

# %%
plotter = pyvista.Plotter(notebook="true")


vtkdata = create_vtk_mesh(domain, domain.topology.dim)
grid = pyvista.UnstructuredGrid(*vtkdata)
actor = plotter.add_mesh(grid, show_edges=True)
plotter.view_xy()
plotter.show()
plotter.close()
# Out:
# WARNING:py.warnings:/Users/jorgenin/Documents/Python/Research/CustomFEMSIM/FEM/lib/python3.11/site-packages/pyvista/jupyter/notebook.py:58: UserWarning: Failed to use notebook backend:
#
# cannot import name 'vtk' from 'trame.widgets' (/Users/jorgenin/Documents/Python/Research/CustomFEMSIM/FEM/lib/python3.11/site-packages/trame/widgets/__init__.py)
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>

# %% [markdown]
# ## Mixed finite element function space, test functions, and solution functions

# %% [markdown]
# We're changing this here to make it just a P1 space to simplify the stefan problem. We will expand to convection if need be.

# %%
P2 = ufl.VectorElement("Lagrange", domain.ufl_cell(), 2)
P1 = ufl.FiniteElement("Lagrange", domain.ufl_cell(), 1)
#TH = ufl.MixedElement([P1, P2, P1])
TH = P1
#P2 is a vector element to account for velocity
#P1 is a scalar element to account for pressure and temperature
W = FunctionSpace(domain, TH)

# %% [markdown]
# Make the system solution function $\mathbf{w} \in \mathbf{W}$ and obtain references to its components $p$, $\mathbf{u}$, and $T$.

# %%
w = Function(W)
T = w #Technically w is just a single temperature problem

# %% [markdown]
# Set constant Prandtl, Rayleigh, and Stefan numbers for the convection-coupled melting benchmark in [5] and [6]. For each we define a Constant for use in the variational form so that FEniCS can more efficiently compile the finite element code.

# %%
prandtl_number = 56.2

Pr = Constant(domain,PETSc.ScalarType(prandtl_number))

rayleigh_number = 3.27e5

Ra = Constant(domain,PETSc.ScalarType(rayleigh_number))

stefan_number = 0.045

Ste = Constant(domain,PETSc.ScalarType(stefan_number))

# %% [markdown]
# Define the idealized linear Boussinesq buoyancy, scaled according to [5]
#
# $$\begin{aligned} \mathbf{f}_B(T) = \frac{\mathrm{Ra}}{\mathrm{Pr}} T\begin{pmatrix} 0 \\ -1 \end{pmatrix}. \end{aligned}$$

# %%
f_B = Ra/Pr*T*Constant(domain,PETSc.ScalarType([0., -1.]))

# %% [markdown]
# Set the regularized semi-phase-field with a central temperature $T_r$ and smoothing parameter $r$.

# %%
regularization_central_temperature = 0.01

T_r = Constant(domain,PETSc.ScalarType(regularization_central_temperature))

regularization_smoothing_parameter = 0.25

r = Constant(domain,PETSc.ScalarType(regularization_smoothing_parameter))

def phi(T):
    return 0.5*(1. + tanh((T_r - T)/r))

# %% [markdown]
# Set the phase-dependent dynamic viscosity

# %%
liquid_dynamic_viscosity = 1.

mu_L = Constant(domain,PETSc.ScalarType(liquid_dynamic_viscosity))


solid_dynamic_viscosity = 1.e8

mu_S = Constant(domain,PETSc.ScalarType(solid_dynamic_viscosity))

def mu(phi):
    
     return mu_L + (mu_S - mu_L)*phi

# %% [markdown]
# Furthermore the benchmark problem involves hot and cold walls with constant temperatures $T_h$ and $T_c$, respectively.

# %%
hot_wall_temperature = 1.

T_h = Constant(domain,PETSc.ScalarType(hot_wall_temperature))

cold_wall_temperature = -0.01

T_c = Constant(domain,PETSc.ScalarType(cold_wall_temperature))

# %%
hot_wall_temperature = 1.

T_h = Constant(domain,PETSc.ScalarType(hot_wall_temperature))

cold_wall_temperature = -0.01

T_c = Constant(domain,PETSc.ScalarType(cold_wall_temperature))

# %% [markdown]
# ## Time discretization
#
# To solve the initial value problem, we will prescribe the initial values, and then take discrete steps forward in time which solve the governing equations.
#
# We set the initial values such that a small layer of melt already exists touching the hot wall.
#
# \begin{align*} p^0 &= 0 \\ \mathbf{u}^0 &= \mathbf{0} \\ T^0 &= \begin{cases} T_h, && x_0 < x_{m,0} \\ T_c, && \mathrm{otherwise} \end{cases} \end{align*}

# %% [markdown]
# Interpolate these values to create the initial solution function

# %%
initial_melt_thickness = .001
x_m = Constant(domain,PETSc.ScalarType(initial_melt_thickness))




def InitialTempExp(x):
    
    return (hot_wall_temperature-cold_wall_temperature)*(x[1]>1-initial_melt_thickness)*np.exp(-1/2*((x[0]-.5)/.06)**2)/(.06*np.sqrt(2*np.pi))+cold_wall_temperature


#w_n = Function(W)
#p_n, u_n, T_n = w_n.split()
T_n = Function(W)
T_n.interpolate(InitialTempExp)

# %%
import matplotlib.pyplot as plt
#dummy function space for plotting
W_dummy = FunctionSpace(domain, ("Lagrange", 1))
cells, types, x = create_vtk_mesh(W_dummy)

grid = pyvista.UnstructuredGrid(cells, types, x)

grid.point_data["T"] = T_n.x.array

plotter = pyvista.Plotter(notebook="true")

viridis = plt.cm.get_cmap("viridis", 25)

sargs = dict(title_font_size=25, label_font_size=20, fmt="%.2e", color="black",
             position_x=0.25, position_y=.9, width=0.5, height=0.1)

warped = grid.warp_by_scalar("T", factor=0)

renderer = plotter.add_mesh(warped, show_edges=True, lighting=False,
                            cmap=viridis, scalar_bar_args=sargs,
                            clim=[0, max( T_n.x.array)])

actor = plotter.add_mesh(grid, show_edges=True)
plotter.view_xy()
plotter.show()
# Out:
# WARNING:py.warnings:/var/folders/2d/bm7xqs8d1fg55jssqgvc9j7c0000gn/T/ipykernel_61235/75112047.py:12: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   viridis = plt.cm.get_cmap("viridis", 25)
#
# WARNING:py.warnings:/Users/jorgenin/Documents/Python/Research/CustomFEMSIM/FEM/lib/python3.11/site-packages/pyvista/jupyter/notebook.py:58: UserWarning: Failed to use notebook backend:
#
# cannot import name 'vtk' from 'trame.widgets' (/Users/jorgenin/Documents/Python/Research/CustomFEMSIM/FEM/lib/python3.11/site-packages/trame/widgets/__init__.py)
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>

# %% [markdown]
# For the time derivative terms $\mathbf{u}_t$, $T_t$, and $\phi_t$, we apply the first-order implicit Euler finite difference time discretization, i.e.
#
# \begin{align*} \mathbf{u}_t = \frac{\mathbf{u}^{n+1} - \mathbf{u}^n}{\Delta t} \\ T_t = \frac{T^{n+1} - T^n}{\Delta t} \\ \phi_t = \frac{\phi^{n+1} - \phi^n}{\Delta t} \end{align*}

# %% [markdown]
# Note
# For our implementation, we will use the shorthand $\mathbf{w} = \mathbf{w}^{n+1}$
# Choose a time step size and set the time derivative terms.

# %%
psi_T = ufl.TestFunction(W)


#u_n is the previous solution essentially
Timestep_size = 4.

Delta_t = Constant(domain,PETSc.ScalarType(Timestep_size))


T_t = (T - T_n)/Delta_t

phi_t = (phi(T) - phi(T_n))/Delta_t

# %% [markdown]
# ## Nonlinear variational form

# %% [markdown]
# We can write the nonlinear system of equations as
#
# $$\begin{aligned} \mathbf{F}(\mathbf{w}) = \mathbf{0} \end{aligned}$$
#
#
# To obtain the finite element weak form, we follow the standard Ritz-Galerkin method extended for mixed finite elements [1]. Therefore, we multiply the system from the left by test functions $\boldsymbol{\psi}$ from the mixed finite element function space $\mathbf{W}$ and integrate over the spatial domain $\Omega$. This gives us the variational problem: Find
# $\mathbf{w} \in \mathbf{W}$ such that
#
# $$\begin{aligned} \mathcal{F}(\boldsymbol{\psi};\mathbf{w}) = \int_\Omega \boldsymbol{\psi}^\mathrm{T} \mathbf{F}(\mathbf{w}) d\mathbf{x} = 0 \quad \forall \boldsymbol{\psi} \in \mathbf{W} \end{aligned}$$
#
#
# Integrating $\mathcal{F}$ by parts yields
#
# $$\begin{aligned} \mathcal{F}(\boldsymbol{\psi};\mathbf{w}) = -(\psi_p,\nabla\cdot\mathbf{u}) \\ + (\boldsymbol{\psi}_u, \mathbf{u}_t + \nabla\mathbf{u}\cdot\mathbf{u} + \mathbf{f}_B(T)) (\nabla\cdot\boldsymbol{\psi}_u,p) + 2\mu(\mathbf{D}(\boldsymbol{\psi}_u),\mathbf{D}(\mathbf{u})) \\ + (\psi_T,T_t - \frac{1}{Ste}\phi_t) + (\nabla \psi_T, \frac{1}{\mathrm{Pr}}\nabla T - T\mathbf{u}) \end{aligned}$$
#
#
# Note
# We denote integrating inner products over the domain as $(v,u) = \int_\Omega v u d \mathbf{x}$ or $(\mathbf{v},\mathbf{u}) = \int_\Omega \mathbf{v} \cdot \mathbf{u} d \mathbf{x}$.
#
# By default FEniCS will numerically integrate with an exact quadrature rule. For this particular problem, this yields a large enough number of quadrature points that FEniCS throws a warning. Let's choose a lower degree quadrature, which will greatly speed up the finite element matrix assembly.

# %%
dxs = ufl.dx(metadata={'quadrature_degree': 8})

# %% [markdown]
# Define the nonlinear variational form $\mathcal{F}$.

# %%
#mass = -psi_p*div(u)

#momentum = dot(psi_u, u_t + dot(grad(u), u) + f_B) - div(psi_u)*p \
#    + 2.*mu(phi(T))*inner(sym(grad(psi_u)), sym(grad(u)))

enthalpy = psi_T*(T_t - 1./Ste*phi_t) + dot(grad(psi_T), 1./Pr*grad(T))
#momentum + enthalpy  
F = (enthalpy)*dx

# %% [markdown]
# We add a penalty method stabilization term $-\gamma(\psi_p,p)$, setting the stabilization parameter $\gamma = 10^{-7}$ as done in [5].

# %%
#penalty_stabilization_parameter = 1.e-7

#gamma = Constant(domain,PETSc.ScalarType(penalty_stabilization_parameter))

#F += -psi_p*gamma*p*dxs

# %% [markdown]
# ## Linearization

# %% [markdown]
# Notice that $\mathcal{F}$ is a nonlinear variational form. FEniCS will solve the nonlinear problem using Newton's method. This requires computing the Jacobian (formally the Gâteaux derivative) of the nonlinear variational form, yielding a a sequence of linearized problems whose solutions may converge to approximate the nonlinear solution.
#
# We could manually define the Jacobian; but thankfully FEniCS can do this for us.
#
# Note
# When solving linear variational problems in FEniCS, one defines the linear variational form using fenics.TrialFunction instead of fenics.Function (while both approaches will need fenics.TestFunction). When solving nonlinear variational problems with FEniCS, we only need fenics.TrialFunction to define the linearized problem, since it is the linearized problem which will be assembled into a linear system and solved.

# %%
q = TrialFunction(W)
JF = derivative(F, w, q)

# %% [markdown]
# ### Boundary conditions

# %% [markdown]
# We need boundary conditions before we can define a nonlinear variational problem (i.e. in this case a boundary value problem).
#
# We physically consider no slip velocity boundary conditions for all boundaries. These manifest as homogeneous Dirichlet boundary conditions. For the temperature boundary conditions, we consider a constant hot temperature on the left wall, a constant cold temperature on the right wall, and adiabatic (i.e. zero heat transfer) conditions on the top and bottom walls. Because the problem's geometry is simple, we can identify the boundaries with the following piece-wise function.
#
# \begin{align*} T(\mathbf{x}) &= \begin{cases} T_h , && x_0 = 0 \\ T_c , && x_0 = 1 \end{cases} \end{align*}

# %%
def HotWall1(x):
    return np.logical_and(np.logical_and(np.isclose(x[1], 1) , x[0]>0.2), x[0]<0.8)

def ColdWall1(x):
     return np.isclose(x[1], 0)

def AdiabaticWall(x):
     return np.logical_or(np.isclose(x[0], 0),np.isclose(x[0], 1))


def walls(x):
    return  np.logical_or(np.logical_or(HotWall1(x),ColdWall1(x)),AdiabaticWall(x))

# %% [markdown]
# Define the boundary conditions on the appropriate subspaces.

# %%
#W_u,_ = W.sub(1).collapse()

#W_T,_ = W.sub(2).collapse()
#u_0 = fem.Function(W_u)
#u_0.x.array[:] = 0

hotwall = fem.locate_dofs_geometrical(W, HotWall1)
coldwall = locate_dofs_geometrical(W, ColdWall1)
#ZeroVelocity = locate_dofs_geometrical(W , walls)


boundary_conditions = [
    #dirichletbc(u_0, ZeroVelocity , W.sub(1)),
    dirichletbc(PETSc.ScalarType(hot_wall_temperature), hotwall, W),
    dirichletbc(PETSc.ScalarType(cold_wall_temperature), coldwall ,W)]

# %%
problem = fem.petsc.NonlinearProblem(F, w, boundary_conditions, JF)

# %% [markdown]
# ### Goal-oriented adaptive mesh refinement (AMR)

# %% [markdown]
# We wish to solve the problem with adaptive mesh refinement (AMR). For this it helps to explain that we have already defined the discrete nonlinear variational problem using FEniCS: Find $\mathbf{w}_h \in \mathbf{W}_h \subset \mathbf{W}(\Omega)$ such that

# %% [markdown]
# \begin{align*} \mathcal{F}(\boldsymbol{\psi}_h;\mathbf{w}_h) = 0 \quad \forall \boldsymbol{\psi}_h \in \mathbf{W}_h \subset \mathbf{W} \end{align*}

# %% [markdown]
# Given this, goal-oriented AMR poses the problem: Find $\mathbf{W}_h \subset \mathbf{W}(\Omega)$ and $\mathbf{w}_h \in \mathbf{W}_h$ such that
#
# $$\begin{aligned} \left| M(\mathbf{w}) - M(\mathbf{w}_h) \right| < \epsilon_M \end{aligned}$$
# where $M$ is some goal functional of the solution which we integrate over the domain, and where $\epsilon_M$ is a prescribed tolerance. Note that since we do not know the exact solution $\mathbf{w}$, this method requires an error estimator. This is detailed in [2]. For our purposes, we only need to define $M$ and $\epsilon_M$.
#
# We choose a goal analagous to the melting rate.

# %% [markdown]
# \begin{align*} M = \int_\Omega \phi_t \hspace{1mm} d\mathbf{x} \end{align*}

# %%
M = phi_t*dxs

# %% [markdown]
# Let's set the tolerance somewhat arbitrarily. For real problems of scientific or engineering interest, one might have accuracy requirements which could help drive this decision.

# %%
epsilon_M = 4.e-5

# %%
solver = dolfinx.nls.petsc.NewtonSolver(MPI.COMM_WORLD, problem)
solver.convergence_criterion = "incremental"
solver.rtol = 4e-5
solver.atol = 1e-5
solver.max_it = 10000
solver.report = True

# %% [markdown]
# We can modify the linear solver in each Newton iteration by accessing the underlying PETSc object.

# %%
ksp = solver.krylov_solver
opts = PETSc.Options()
option_prefix = ksp.getOptionsPrefix()
opts[f"{option_prefix}ksp_type"] = "cg"
opts[f"{option_prefix}pc_type"] = "gamg"
opts[f"{option_prefix}pc_factor_mat_solver_type"] = "mumps"
opts[f"{option_prefix}ksp_max_it"] = 1000
ksp.setFromOptions()

# %% [markdown]
# We are now ready to solve the non-linear problem. We assert that the solver has converged and print the number of iterations.

# %%
log.set_log_level(log.LogLevel.INFO)
#n, converged = solver.solve(w)
#print(f"Number of interations: {n:d}")

# %%
import pyvista
import matplotlib.pyplot as plt
t=0

phi_ex = lambda arr:  0.5* (1 + np.tanh(arr-regularization_central_temperature)/regularization_smoothing_parameter)
pyvista.set_jupyter_backend('panel')
grid = pyvista.UnstructuredGrid(*create_vtk_mesh(W))

plotter = pyvista.Plotter(notebook="true")
plotter.open_gif("W_time.gif")

grid.point_data["Solid Volume Fraction"] = phi_ex(w.x.array)*0
warped = grid.warp_by_scalar("Solid Volume Fraction", factor=1)

viridis = plt.cm.get_cmap("viridis", 25)
sargs = dict(title_font_size=25, label_font_size=20, fmt="%.2e", color="black",
             position_x=0.25, position_y=0.9, width=0.5, height=0.1)

renderer = plotter.add_mesh(warped, show_edges=True, lighting=False,
                            cmap=viridis, scalar_bar_args=sargs,
                            clim=[0, 1])
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='600733e9-ca71-4a57-8406-a6b9736573a2'>
#   <div id="e534d4c1-08a3-4f94-858c-12870bc92137" data-root-id="600733e9-ca71-4a57-8406-a6b9736573a2" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"48cb5682-bada-4531-876c-ad89de12bfbc":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"600733e9-ca71-4a57-8406-a6b9736573a2"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"6d1c32fe-43e8-425b-b439-bddc7502770d","attributes":{"plot_id":"600733e9-ca71-4a57-8406-a6b9736573a2","comm_id":"70d4b00d7579421db81661b3f8819d99","client_comm_id":"95ef0ffd72f84471b9daef05c0ac037e"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"48cb5682-bada-4531-876c-ad89de12bfbc","roots":{"600733e9-ca71-4a57-8406-a6b9736573a2":"e534d4c1-08a3-4f94-858c-12870bc92137"},"root_ids":["600733e9-ca71-4a57-8406-a6b9736573a2"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root['vtk'] !== undefined) && ( root['vtk'] !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# WARNING:py.warnings:/var/folders/2d/bm7xqs8d1fg55jssqgvc9j7c0000gn/T/ipykernel_61235/4171068536.py:6: PyVistaDeprecationWarning: `panel` backend is deprecated and is planned for future removal.
#   pyvista.set_jupyter_backend('panel')
#
# WARNING:py.warnings:/var/folders/2d/bm7xqs8d1fg55jssqgvc9j7c0000gn/T/ipykernel_61235/4171068536.py:15: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   viridis = plt.cm.get_cmap("viridis", 25)

# %%
plotter.view_xy()
num_steps =100
dt = 10
for i in range(num_steps):
    t += dt

    ## Update the right hand side reusing the initial vector
    #with b.localForm() as loc_b:
    #    loc_b.set(0)
    #fem.petsc.assemble_vector(b, linear_form)
    
    # Apply Dirichlet boundary condition to the vector
    #fem.petsc.apply_lifting(b, [bilinear_form], [[bc]])
    #b.ghostUpdate(addv=PETSc.InsertMode.ADD_VALUES, mode=PETSc.ScatterMode.REVERSE)
    #fem.petsc.set_bc(b, [bc])

    # Solve linear problem
    solver.solve(w)
    w.x.scatter_forward()

    # Update solution at previous time step (u_n)
    T_n.x.array[:] = w.x.array

    # Write solution to file
    # Update plot
    

    warped = grid.warp_by_scalar("Solid Volume Fraction", factor=0)
    plotter.update_coordinates(warped.points.copy(), render=True)
    plotter.update_scalars(phi_ex(w.x.array), render=True)
    plotter.render()
    plotter.write_frame()
plotter.close()
# Out:
# 2023-09-02 10:43:48.064 (   2.820s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:48.268 (   3.024s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:48.303 (   3.060s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 1.69802 (tol = 1e-05) r (rel) = 0.138496(tol = 4e-05)
# 2023-09-02 10:43:48.335 (   3.091s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:48.368 (   3.125s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 0.0695761 (tol = 1e-05) r (rel) = 0.00567486(tol = 4e-05)
# 2023-09-02 10:43:48.398 (   3.155s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:48.431 (   3.187s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 4: r (abs) = 0.000174444 (tol = 1e-05) r (rel) = 1.42283e-05(tol = 4e-05)
# 2023-09-02 10:43:48.431 (   3.187s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 4 iterations and 36 linear solver iterations.
# 2023-09-02 10:43:48.523 (   3.280s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:48.586 (   3.343s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:48.619 (   3.376s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.695204 (tol = 1e-05) r (rel) = 0.155192(tol = 4e-05)
# 2023-09-02 10:43:48.649 (   3.406s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:48.683 (   3.440s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 0.0174432 (tol = 1e-05) r (rel) = 0.00389389(tol = 4e-05)
# 2023-09-02 10:43:48.713 (   3.470s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:48.747 (   3.504s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 4: r (abs) = 1.32663e-05 (tol = 1e-05) r (rel) = 2.96147e-06(tol = 4e-05)
# 2023-09-02 10:43:48.747 (   3.504s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 4 iterations and 36 linear solver iterations.
# 2023-09-02 10:43:48.802 (   3.559s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:48.866 (   3.622s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:48.898 (   3.655s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.348821 (tol = 1e-05) r (rel) = 0.119052(tol = 4e-05)
# 2023-09-02 10:43:48.928 (   3.685s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:48.960 (   3.717s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 0.00509651 (tol = 1e-05) r (rel) = 0.00173943(tol = 4e-05)
# 2023-09-02 10:43:48.990 (   3.747s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:49.023 (   3.780s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 4: r (abs) = 1.24749e-06 (tol = 1e-05) r (rel) = 4.25766e-07(tol = 4e-05)
# 2023-09-02 10:43:49.023 (   3.780s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 4 iterations and 36 linear solver iterations.
# 2023-09-02 10:43:49.074 (   3.831s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:49.135 (   3.891s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:49.167 (   3.924s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.212067 (tol = 1e-05) r (rel) = 0.0937867(tol = 4e-05)
# 2023-09-02 10:43:49.197 (   3.954s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:49.230 (   3.987s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 0.00200127 (tol = 1e-05) r (rel) = 0.000885061(tol = 4e-05)
# 2023-09-02 10:43:49.262 (   4.019s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:49.296 (   4.053s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 4: r (abs) = 1.99615e-07 (tol = 1e-05) r (rel) = 8.82796e-08(tol = 4e-05)
# 2023-09-02 10:43:49.296 (   4.053s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 4 iterations and 35 linear solver iterations.
# 2023-09-02 10:43:49.352 (   4.109s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:49.415 (   4.171s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:49.448 (   4.205s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.144303 (tol = 1e-05) r (rel) = 0.0766269(tol = 4e-05)
# 2023-09-02 10:43:49.479 (   4.236s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:49.513 (   4.269s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 0.000941261 (tol = 1e-05) r (rel) = 0.000499822(tol = 4e-05)
# 2023-09-02 10:43:49.544 (   4.301s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:49.578 (   4.334s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 4: r (abs) = 4.45504e-08 (tol = 1e-05) r (rel) = 2.36569e-08(tol = 4e-05)
# 2023-09-02 10:43:49.578 (   4.334s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 4 iterations and 35 linear solver iterations.
# 2023-09-02 10:43:49.630 (   4.387s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:49.693 (   4.450s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:49.727 (   4.483s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.106836 (tol = 1e-05) r (rel) = 0.06501(tol = 4e-05)
# 2023-09-02 10:43:49.758 (   4.515s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:49.791 (   4.548s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 0.000507204 (tol = 1e-05) r (rel) = 0.000308636(tol = 4e-05)
# 2023-09-02 10:43:49.822 (   4.579s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:49.856 (   4.612s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 4: r (abs) = 1.29133e-08 (tol = 1e-05) r (rel) = 7.85781e-09(tol = 4e-05)
# 2023-09-02 10:43:49.856 (   4.613s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 4 iterations and 35 linear solver iterations.
# 2023-09-02 10:43:49.910 (   4.667s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:49.972 (   4.728s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:50.003 (   4.760s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0853823 (tol = 1e-05) r (rel) = 0.0575964(tol = 4e-05)
# 2023-09-02 10:43:50.033 (   4.790s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:50.067 (   4.824s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 0.00031364 (tol = 1e-05) r (rel) = 0.000211572(tol = 4e-05)
# 2023-09-02 10:43:50.099 (   4.856s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:50.132 (   4.889s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 4: r (abs) = 4.8418e-09 (tol = 1e-05) r (rel) = 3.26614e-09(tol = 4e-05)
# 2023-09-02 10:43:50.132 (   4.889s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 4 iterations and 34 linear solver iterations.
# 2023-09-02 10:43:50.184 (   4.941s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:50.246 (   5.002s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:50.276 (   5.032s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0735235 (tol = 1e-05) r (rel) = 0.0536021(tol = 4e-05)
# 2023-09-02 10:43:50.306 (   5.063s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:50.339 (   5.095s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 0.000235525 (tol = 1e-05) r (rel) = 0.000171709(tol = 4e-05)
# 2023-09-02 10:43:50.369 (   5.126s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:50.402 (   5.159s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 4: r (abs) = 2.92543e-09 (tol = 1e-05) r (rel) = 2.13278e-09(tol = 4e-05)
# 2023-09-02 10:43:50.402 (   5.159s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 4 iterations and 34 linear solver iterations.
# 2023-09-02 10:43:50.454 (   5.211s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:50.515 (   5.272s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:50.545 (   5.302s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0676507 (tol = 1e-05) r (rel) = 0.05225(tol = 4e-05)
# 2023-09-02 10:43:50.576 (   5.332s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:50.606 (   5.363s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 0.000221992 (tol = 1e-05) r (rel) = 0.000171456(tol = 4e-05)
# 2023-09-02 10:43:50.637 (   5.394s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:50.672 (   5.428s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 4: r (abs) = 4.41134e-09 (tol = 1e-05) r (rel) = 3.4071e-09(tol = 4e-05)
# 2023-09-02 10:43:50.672 (   5.428s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 4 iterations and 34 linear solver iterations.
# 2023-09-02 10:43:50.724 (   5.480s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:50.785 (   5.542s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:50.815 (   5.572s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0651645 (tol = 1e-05) r (rel) = 0.0525131(tol = 4e-05)
# 2023-09-02 10:43:50.846 (   5.603s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:50.876 (   5.633s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 0.000236069 (tol = 1e-05) r (rel) = 0.000190237(tol = 4e-05)
# 2023-09-02 10:43:50.907 (   5.664s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:50.942 (   5.699s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 4: r (abs) = 5.37199e-09 (tol = 1e-05) r (rel) = 4.32904e-09(tol = 4e-05)
# 2023-09-02 10:43:50.942 (   5.699s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 4 iterations and 34 linear solver iterations.
# 2023-09-02 10:43:50.994 (   5.751s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:51.056 (   5.812s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:51.086 (   5.843s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0639926 (tol = 1e-05) r (rel) = 0.0532427(tol = 4e-05)
# 2023-09-02 10:43:51.117 (   5.874s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:51.147 (   5.904s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 0.000249235 (tol = 1e-05) r (rel) = 0.000207367(tol = 4e-05)
# 2023-09-02 10:43:51.178 (   5.935s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:51.211 (   5.968s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 4: r (abs) = 6.16773e-09 (tol = 1e-05) r (rel) = 5.13163e-09(tol = 4e-05)
# 2023-09-02 10:43:51.211 (   5.968s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 4 iterations and 33 linear solver iterations.
# 2023-09-02 10:43:51.263 (   6.020s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:51.325 (   6.082s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:51.355 (   6.112s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.06264 (tol = 1e-05) r (rel) = 0.0534988(tol = 4e-05)
# 2023-09-02 10:43:51.386 (   6.143s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:51.417 (   6.174s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 0.000246719 (tol = 1e-05) r (rel) = 0.000210715(tol = 4e-05)
# 2023-09-02 10:43:51.448 (   6.205s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:51.480 (   6.237s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 4: r (abs) = 6.00653e-09 (tol = 1e-05) r (rel) = 5.12998e-09(tol = 4e-05)
# 2023-09-02 10:43:51.480 (   6.237s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 4 iterations and 33 linear solver iterations.
# 2023-09-02 10:43:51.533 (   6.290s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:51.594 (   6.351s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:51.625 (   6.381s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0603103 (tol = 1e-05) r (rel) = 0.052795(tol = 4e-05)
# 2023-09-02 10:43:51.656 (   6.412s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:51.686 (   6.443s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 0.000226565 (tol = 1e-05) r (rel) = 0.000198333(tol = 4e-05)
# 2023-09-02 10:43:51.717 (   6.474s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:51.752 (   6.509s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 4: r (abs) = 5.13287e-09 (tol = 1e-05) r (rel) = 4.49326e-09(tol = 4e-05)
# 2023-09-02 10:43:51.752 (   6.509s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 4 iterations and 34 linear solver iterations.
# 2023-09-02 10:43:51.806 (   6.563s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:51.868 (   6.624s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:51.898 (   6.655s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0568722 (tol = 1e-05) r (rel) = 0.0511126(tol = 4e-05)
# 2023-09-02 10:43:51.929 (   6.686s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:51.959 (   6.716s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 0.000194904 (tol = 1e-05) r (rel) = 0.000175166(tol = 4e-05)
# 2023-09-02 10:43:51.990 (   6.747s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:52.025 (   6.782s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 4: r (abs) = 4.0497e-09 (tol = 1e-05) r (rel) = 3.63957e-09(tol = 4e-05)
# 2023-09-02 10:43:52.025 (   6.782s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 4 iterations and 34 linear solver iterations.
# 2023-09-02 10:43:52.078 (   6.835s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:52.140 (   6.897s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:52.170 (   6.927s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0526361 (tol = 1e-05) r (rel) = 0.0487267(tol = 4e-05)
# 2023-09-02 10:43:52.201 (   6.958s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:52.231 (   6.988s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 0.000159846 (tol = 1e-05) r (rel) = 0.000147974(tol = 4e-05)
# 2023-09-02 10:43:52.262 (   7.019s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:52.297 (   7.054s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 4: r (abs) = 3.08289e-09 (tol = 1e-05) r (rel) = 2.85392e-09(tol = 4e-05)
# 2023-09-02 10:43:52.297 (   7.054s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 4 iterations and 34 linear solver iterations.
# 2023-09-02 10:43:52.351 (   7.107s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:52.412 (   7.169s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:52.443 (   7.200s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0480642 (tol = 1e-05) r (rel) = 0.0459922(tol = 4e-05)
# 2023-09-02 10:43:52.474 (   7.231s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:52.504 (   7.261s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 0.000127359 (tol = 1e-05) r (rel) = 0.000121869(tol = 4e-05)
# 2023-09-02 10:43:52.536 (   7.293s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:52.571 (   7.327s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 4: r (abs) = 2.31529e-09 (tol = 1e-05) r (rel) = 2.21547e-09(tol = 4e-05)
# 2023-09-02 10:43:52.571 (   7.327s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 4 iterations and 34 linear solver iterations.
# 2023-09-02 10:43:52.624 (   7.381s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:52.686 (   7.443s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:52.716 (   7.473s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0435561 (tol = 1e-05) r (rel) = 0.0432023(tol = 4e-05)
# 2023-09-02 10:43:52.748 (   7.504s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:52.778 (   7.535s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 0.000100227 (tol = 1e-05) r (rel) = 9.94131e-05(tol = 4e-05)
# 2023-09-02 10:43:52.809 (   7.566s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:52.844 (   7.601s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 4: r (abs) = 1.72558e-09 (tol = 1e-05) r (rel) = 1.71156e-09(tol = 4e-05)
# 2023-09-02 10:43:52.844 (   7.601s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 4 iterations and 34 linear solver iterations.
# 2023-09-02 10:43:52.898 (   7.655s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:52.960 (   7.717s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:52.990 (   7.747s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0393641 (tol = 1e-05) r (rel) = 0.0405414(tol = 4e-05)
# 2023-09-02 10:43:53.022 (   7.778s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:53.052 (   7.808s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 7.88681e-05 (tol = 1e-05) r (rel) = 8.12269e-05(tol = 4e-05)
# 2023-09-02 10:43:53.083 (   7.840s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:53.118 (   7.875s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 4: r (abs) = 1.32728e-09 (tol = 1e-05) r (rel) = 1.36698e-09(tol = 4e-05)
# 2023-09-02 10:43:53.118 (   7.875s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 4 iterations and 34 linear solver iterations.
# 2023-09-02 10:43:53.171 (   7.928s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:53.233 (   7.989s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:53.263 (   8.020s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0356017 (tol = 1e-05) r (rel) = 0.0380976(tol = 4e-05)
# 2023-09-02 10:43:53.294 (   8.051s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:53.325 (   8.082s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 6.25229e-05 (tol = 1e-05) r (rel) = 6.69062e-05(tol = 4e-05)
# 2023-09-02 10:43:53.356 (   8.113s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:53.391 (   8.148s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 4: r (abs) = 1.07321e-09 (tol = 1e-05) r (rel) = 1.14845e-09(tol = 4e-05)
# 2023-09-02 10:43:53.391 (   8.148s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 4 iterations and 34 linear solver iterations.
# 2023-09-02 10:43:53.445 (   8.202s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:53.507 (   8.264s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:53.538 (   8.295s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.032289 (tol = 1e-05) r (rel) = 0.0358955(tol = 4e-05)
# 2023-09-02 10:43:53.569 (   8.326s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:53.600 (   8.356s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 5.01107e-05 (tol = 1e-05) r (rel) = 5.57078e-05(tol = 4e-05)
# 2023-09-02 10:43:53.631 (   8.388s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:53.666 (   8.423s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 4: r (abs) = 8.52812e-10 (tol = 1e-05) r (rel) = 9.48067e-10(tol = 4e-05)
# 2023-09-02 10:43:53.666 (   8.423s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 4 iterations and 34 linear solver iterations.
# 2023-09-02 10:43:53.721 (   8.478s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:53.783 (   8.540s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:53.813 (   8.570s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0293971 (tol = 1e-05) r (rel) = 0.033926(tol = 4e-05)
# 2023-09-02 10:43:53.845 (   8.601s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:53.875 (   8.632s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 4.06496e-05 (tol = 1e-05) r (rel) = 4.69122e-05(tol = 4e-05)
# 2023-09-02 10:43:53.906 (   8.663s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:53.944 (   8.700s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 4: r (abs) = 6.11163e-10 (tol = 1e-05) r (rel) = 7.05319e-10(tol = 4e-05)
# 2023-09-02 10:43:53.944 (   8.700s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 4 iterations and 35 linear solver iterations.
# 2023-09-02 10:43:53.999 (   8.756s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:54.063 (   8.820s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:54.094 (   8.850s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0268777 (tol = 1e-05) r (rel) = 0.0321664(tol = 4e-05)
# 2023-09-02 10:43:54.125 (   8.882s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:54.156 (   8.912s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 3.33718e-05 (tol = 1e-05) r (rel) = 3.99384e-05(tol = 4e-05)
# 2023-09-02 10:43:54.156 (   8.912s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 24 linear solver iterations.
# 2023-09-02 10:43:54.208 (   8.965s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:54.270 (   9.027s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:54.300 (   9.057s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0246789 (tol = 1e-05) r (rel) = 0.0305902(tol = 4e-05)
# 2023-09-02 10:43:54.332 (   9.089s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:54.363 (   9.119s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 2.77088e-05 (tol = 1e-05) r (rel) = 3.43458e-05(tol = 4e-05)
# 2023-09-02 10:43:54.363 (   9.119s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 24 linear solver iterations.
# 2023-09-02 10:43:54.417 (   9.174s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:54.479 (   9.236s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:54.509 (   9.266s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0227528 (tol = 1e-05) r (rel) = 0.0291726(tol = 4e-05)
# 2023-09-02 10:43:54.541 (   9.298s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:54.572 (   9.328s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 2.3248e-05 (tol = 1e-05) r (rel) = 2.98075e-05(tol = 4e-05)
# 2023-09-02 10:43:54.572 (   9.328s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 24 linear solver iterations.
# 2023-09-02 10:43:54.624 (   9.381s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:54.686 (   9.443s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:54.716 (   9.473s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0210575 (tol = 1e-05) r (rel) = 0.0278914(tol = 4e-05)
# 2023-09-02 10:43:54.748 (   9.505s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:54.780 (   9.537s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 1.96913e-05 (tol = 1e-05) r (rel) = 2.60818e-05(tol = 4e-05)
# 2023-09-02 10:43:54.780 (   9.537s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 25 linear solver iterations.
# 2023-09-02 10:43:54.835 (   9.591s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:54.897 (   9.654s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:54.927 (   9.684s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.019558 (tol = 1e-05) r (rel) = 0.026728(tol = 4e-05)
# 2023-09-02 10:43:54.959 (   9.716s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:54.991 (   9.748s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 1.68225e-05 (tol = 1e-05) r (rel) = 2.29896e-05(tol = 4e-05)
# 2023-09-02 10:43:54.991 (   9.748s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 25 linear solver iterations.
# 2023-09-02 10:43:55.044 (   9.801s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:55.107 (   9.863s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:55.137 (   9.894s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0182249 (tol = 1e-05) r (rel) = 0.0256666(tol = 4e-05)
# 2023-09-02 10:43:55.169 (   9.926s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:55.202 (   9.958s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 1.44833e-05 (tol = 1e-05) r (rel) = 2.03972e-05(tol = 4e-05)
# 2023-09-02 10:43:55.202 (   9.959s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 25 linear solver iterations.
# 2023-09-02 10:43:55.256 (  10.012s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:55.318 (  10.075s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:55.349 (  10.106s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0170339 (tol = 1e-05) r (rel) = 0.0246941(tol = 4e-05)
# 2023-09-02 10:43:55.381 (  10.138s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:55.414 (  10.171s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 1.25565e-05 (tol = 1e-05) r (rel) = 1.82033e-05(tol = 4e-05)
# 2023-09-02 10:43:55.414 (  10.171s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 25 linear solver iterations.
# 2023-09-02 10:43:55.468 (  10.224s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:55.531 (  10.288s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:55.562 (  10.319s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0159648 (tol = 1e-05) r (rel) = 0.0237994(tol = 4e-05)
# 2023-09-02 10:43:55.596 (  10.352s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:55.630 (  10.387s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 1.09548e-05 (tol = 1e-05) r (rel) = 1.63308e-05(tol = 4e-05)
# 2023-09-02 10:43:55.630 (  10.387s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 25 linear solver iterations.
# 2023-09-02 10:43:55.687 (  10.444s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:55.753 (  10.509s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:55.784 (  10.541s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.015001 (tol = 1e-05) r (rel) = 0.0229733(tol = 4e-05)
# 2023-09-02 10:43:55.817 (  10.573s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:55.850 (  10.607s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 9.6119e-06 (tol = 1e-05) r (rel) = 1.47201e-05(tol = 4e-05)
# 2023-09-02 10:43:55.850 (  10.607s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 25 linear solver iterations.
# 2023-09-02 10:43:55.907 (  10.664s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:55.972 (  10.729s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:56.004 (  10.761s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0141284 (tol = 1e-05) r (rel) = 0.0222079(tol = 4e-05)
# 2023-09-02 10:43:56.038 (  10.795s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:56.072 (  10.829s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 8.47724e-06 (tol = 1e-05) r (rel) = 1.3325e-05(tol = 4e-05)
# 2023-09-02 10:43:56.072 (  10.829s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 25 linear solver iterations.
# 2023-09-02 10:43:56.128 (  10.885s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:56.194 (  10.950s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:56.225 (  10.982s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0133353 (tol = 1e-05) r (rel) = 0.0214966(tol = 4e-05)
# 2023-09-02 10:43:56.258 (  11.015s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:56.292 (  11.049s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 7.5117e-06 (tol = 1e-05) r (rel) = 1.21089e-05(tol = 4e-05)
# 2023-09-02 10:43:56.292 (  11.049s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 25 linear solver iterations.
# 2023-09-02 10:43:56.345 (  11.101s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:56.409 (  11.166s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:56.441 (  11.197s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0126119 (tol = 1e-05) r (rel) = 0.0208336(tol = 4e-05)
# 2023-09-02 10:43:56.474 (  11.231s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:56.508 (  11.265s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 6.68471e-06 (tol = 1e-05) r (rel) = 1.10425e-05(tol = 4e-05)
# 2023-09-02 10:43:56.508 (  11.265s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 25 linear solver iterations.
# 2023-09-02 10:43:56.561 (  11.318s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:56.626 (  11.383s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:56.657 (  11.414s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0119495 (tol = 1e-05) r (rel) = 0.020214(tol = 4e-05)
# 2023-09-02 10:43:56.691 (  11.447s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:56.722 (  11.479s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 5.97215e-06 (tol = 1e-05) r (rel) = 1.01026e-05(tol = 4e-05)
# 2023-09-02 10:43:56.722 (  11.479s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 24 linear solver iterations.
# 2023-09-02 10:43:56.777 (  11.533s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:56.840 (  11.597s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:56.871 (  11.628s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0113411 (tol = 1e-05) r (rel) = 0.0196335(tol = 4e-05)
# 2023-09-02 10:43:56.904 (  11.660s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:56.934 (  11.691s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 5.3548e-06 (tol = 1e-05) r (rel) = 9.2701e-06(tol = 4e-05)
# 2023-09-02 10:43:56.934 (  11.691s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 24 linear solver iterations.
# 2023-09-02 10:43:56.987 (  11.744s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:57.050 (  11.807s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:57.081 (  11.838s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0107805 (tol = 1e-05) r (rel) = 0.0190883(tol = 4e-05)
# 2023-09-02 10:43:57.114 (  11.871s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:57.145 (  11.902s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 4.81723e-06 (tol = 1e-05) r (rel) = 8.52956e-06(tol = 4e-05)
# 2023-09-02 10:43:57.145 (  11.902s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 24 linear solver iterations.
# 2023-09-02 10:43:57.198 (  11.954s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:57.261 (  12.017s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:57.291 (  12.048s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0102623 (tol = 1e-05) r (rel) = 0.0185751(tol = 4e-05)
# 2023-09-02 10:43:57.324 (  12.080s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:57.354 (  12.111s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 4.34693e-06 (tol = 1e-05) r (rel) = 7.86814e-06(tol = 4e-05)
# 2023-09-02 10:43:57.354 (  12.111s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 24 linear solver iterations.
# 2023-09-02 10:43:57.408 (  12.165s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:57.473 (  12.230s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:57.505 (  12.262s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.00978177 (tol = 1e-05) r (rel) = 0.018091(tol = 4e-05)
# 2023-09-02 10:43:57.539 (  12.296s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:57.572 (  12.329s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 3.93367e-06 (tol = 1e-05) r (rel) = 7.27518e-06(tol = 4e-05)
# 2023-09-02 10:43:57.572 (  12.329s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 24 linear solver iterations.
# 2023-09-02 10:43:57.631 (  12.387s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:57.696 (  12.453s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:57.728 (  12.485s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.00933497 (tol = 1e-05) r (rel) = 0.0176333(tol = 4e-05)
# 2023-09-02 10:43:57.762 (  12.518s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:57.793 (  12.550s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 3.56904e-06 (tol = 1e-05) r (rel) = 6.74173e-06(tol = 4e-05)
# 2023-09-02 10:43:57.793 (  12.550s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 24 linear solver iterations.
# 2023-09-02 10:43:57.847 (  12.604s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:57.913 (  12.670s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:57.945 (  12.701s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.00891831 (tol = 1e-05) r (rel) = 0.0171996(tol = 4e-05)
# 2023-09-02 10:43:57.978 (  12.735s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:58.010 (  12.766s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 3.24604e-06 (tol = 1e-05) r (rel) = 6.26021e-06(tol = 4e-05)
# 2023-09-02 10:43:58.010 (  12.766s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 24 linear solver iterations.
# 2023-09-02 10:43:58.064 (  12.821s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:58.130 (  12.887s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:58.162 (  12.918s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.00852864 (tol = 1e-05) r (rel) = 0.0167877(tol = 4e-05)
# 2023-09-02 10:43:58.195 (  12.952s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:58.227 (  12.983s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 2.95882e-06 (tol = 1e-05) r (rel) = 5.82411e-06(tol = 4e-05)
# 2023-09-02 10:43:58.227 (  12.983s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 24 linear solver iterations.
# 2023-09-02 10:43:58.281 (  13.037s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:58.347 (  13.103s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:58.378 (  13.135s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.00816319 (tol = 1e-05) r (rel) = 0.0163957(tol = 4e-05)
# 2023-09-02 10:43:58.412 (  13.168s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:58.444 (  13.201s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 2.70245e-06 (tol = 1e-05) r (rel) = 5.42786e-06(tol = 4e-05)
# 2023-09-02 10:43:58.444 (  13.201s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 24 linear solver iterations.
# 2023-09-02 10:43:58.504 (  13.261s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:58.571 (  13.327s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:58.604 (  13.361s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.00781949 (tol = 1e-05) r (rel) = 0.0160218(tol = 4e-05)
# 2023-09-02 10:43:58.639 (  13.396s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:58.671 (  13.428s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 2.47279e-06 (tol = 1e-05) r (rel) = 5.06663e-06(tol = 4e-05)
# 2023-09-02 10:43:58.671 (  13.428s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 24 linear solver iterations.
# 2023-09-02 10:43:58.728 (  13.485s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:58.796 (  13.553s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:58.829 (  13.586s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.00749535 (tol = 1e-05) r (rel) = 0.0156642(tol = 4e-05)
# 2023-09-02 10:43:58.864 (  13.621s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:58.896 (  13.653s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 2.2663e-06 (tol = 1e-05) r (rel) = 4.73622e-06(tol = 4e-05)
# 2023-09-02 10:43:58.896 (  13.653s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 24 linear solver iterations.
# 2023-09-02 10:43:58.956 (  13.713s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:59.020 (  13.777s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:43:59.051 (  13.808s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.00718882 (tol = 1e-05) r (rel) = 0.0153214(tol = 4e-05)
# ...
# 2023-09-02 10:44:07.479 (  22.236s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 26 linear solver iterations.
# 2023-09-02 10:44:07.535 (  22.292s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:07.601 (  22.358s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:07.632 (  22.389s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.000923007 (tol = 1e-05) r (rel) = 0.00549487(tol = 4e-05)
# 2023-09-02 10:44:07.666 (  22.423s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:07.702 (  22.459s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 3.61383e-08 (tol = 1e-05) r (rel) = 2.1514e-07(tol = 4e-05)
# 2023-09-02 10:44:07.702 (  22.459s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 26 linear solver iterations.
# 2023-09-02 10:44:07.758 (  22.515s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:07.824 (  22.580s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:07.854 (  22.611s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.000854529 (tol = 1e-05) r (rel) = 0.00528744(tol = 4e-05)
# 2023-09-02 10:44:07.888 (  22.645s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:07.923 (  22.680s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 3.13317e-08 (tol = 1e-05) r (rel) = 1.93866e-07(tol = 4e-05)
# 2023-09-02 10:44:07.924 (  22.680s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 26 linear solver iterations.
# 2023-09-02 10:44:07.978 (  22.735s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:08.042 (  22.799s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:08.072 (  22.829s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.00079006 (tol = 1e-05) r (rel) = 0.00508433(tol = 4e-05)
# 2023-09-02 10:44:08.106 (  22.863s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:08.141 (  22.898s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 2.71372e-08 (tol = 1e-05) r (rel) = 1.74638e-07(tol = 4e-05)
# 2023-09-02 10:44:08.141 (  22.898s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 26 linear solver iterations.
# 2023-09-02 10:44:08.196 (  22.953s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:08.261 (  23.018s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:08.292 (  23.048s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.000729483 (tol = 1e-05) r (rel) = 0.0048857(tol = 4e-05)
# 2023-09-02 10:44:08.326 (  23.083s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:08.362 (  23.118s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 2.34875e-08 (tol = 1e-05) r (rel) = 1.57307e-07(tol = 4e-05)
# 2023-09-02 10:44:08.362 (  23.118s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 26 linear solver iterations.
# 2023-09-02 10:44:08.419 (  23.176s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:08.484 (  23.241s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:08.515 (  23.272s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.000672675 (tol = 1e-05) r (rel) = 0.00469173(tol = 4e-05)
# 2023-09-02 10:44:08.549 (  23.306s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:08.585 (  23.342s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 2.03205e-08 (tol = 1e-05) r (rel) = 1.4173e-07(tol = 4e-05)
# 2023-09-02 10:44:08.585 (  23.342s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 26 linear solver iterations.
# 2023-09-02 10:44:08.642 (  23.399s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:08.707 (  23.464s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:08.738 (  23.495s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0006195 (tol = 1e-05) r (rel) = 0.00450254(tol = 4e-05)
# 2023-09-02 10:44:08.772 (  23.529s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:08.808 (  23.565s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 1.75794e-08 (tol = 1e-05) r (rel) = 1.27767e-07(tol = 4e-05)
# 2023-09-02 10:44:08.808 (  23.565s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 26 linear solver iterations.
# 2023-09-02 10:44:08.865 (  23.622s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:08.930 (  23.687s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:08.960 (  23.717s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.000569818 (tol = 1e-05) r (rel) = 0.00431825(tol = 4e-05)
# 2023-09-02 10:44:08.996 (  23.753s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:09.033 (  23.789s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 1.52125e-08 (tol = 1e-05) r (rel) = 1.15285e-07(tol = 4e-05)
# 2023-09-02 10:44:09.033 (  23.789s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 26 linear solver iterations.
# 2023-09-02 10:44:09.090 (  23.847s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:09.158 (  23.915s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:09.191 (  23.948s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.000523484 (tol = 1e-05) r (rel) = 0.00413895(tol = 4e-05)
# 2023-09-02 10:44:09.227 (  23.983s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:09.264 (  24.020s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 1.3173e-08 (tol = 1e-05) r (rel) = 1.04153e-07(tol = 4e-05)
# 2023-09-02 10:44:09.264 (  24.020s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 26 linear solver iterations.
# 2023-09-02 10:44:09.323 (  24.080s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:09.390 (  24.147s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:09.422 (  24.179s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.000480349 (tol = 1e-05) r (rel) = 0.00396471(tol = 4e-05)
# 2023-09-02 10:44:09.458 (  24.214s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:09.493 (  24.250s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 1.14188e-08 (tol = 1e-05) r (rel) = 9.42491e-08(tol = 4e-05)
# 2023-09-02 10:44:09.493 (  24.250s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 26 linear solver iterations.
# 2023-09-02 10:44:09.548 (  24.305s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:09.613 (  24.370s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:09.644 (  24.401s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.000440261 (tol = 1e-05) r (rel) = 0.00379561(tol = 4e-05)
# 2023-09-02 10:44:09.678 (  24.435s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:09.713 (  24.470s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 9.91229e-09 (tol = 1e-05) r (rel) = 8.54564e-08(tol = 4e-05)
# 2023-09-02 10:44:09.713 (  24.470s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 26 linear solver iterations.
# 2023-09-02 10:44:09.771 (  24.527s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:09.836 (  24.593s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:09.867 (  24.624s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.000403069 (tol = 1e-05) r (rel) = 0.00363166(tol = 4e-05)
# 2023-09-02 10:44:09.901 (  24.658s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:09.937 (  24.694s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 8.61976e-09 (tol = 1e-05) r (rel) = 7.76643e-08(tol = 4e-05)
# 2023-09-02 10:44:09.937 (  24.694s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 26 linear solver iterations.
# 2023-09-02 10:44:09.992 (  24.749s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:10.059 (  24.815s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:10.089 (  24.846s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.000368618 (tol = 1e-05) r (rel) = 0.0034729(tol = 4e-05)
# 2023-09-02 10:44:10.124 (  24.880s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:10.159 (  24.916s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 7.51153e-09 (tol = 1e-05) r (rel) = 7.0769e-08(tol = 4e-05)
# 2023-09-02 10:44:10.159 (  24.916s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 26 linear solver iterations.
# 2023-09-02 10:44:10.214 (  24.971s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:10.279 (  25.036s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:10.310 (  25.067s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.000336758 (tol = 1e-05) r (rel) = 0.00331931(tol = 4e-05)
# 2023-09-02 10:44:10.344 (  25.101s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:10.379 (  25.136s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 6.56142e-09 (tol = 1e-05) r (rel) = 6.46737e-08(tol = 4e-05)
# 2023-09-02 10:44:10.379 (  25.136s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 26 linear solver iterations.
# 2023-09-02 10:44:10.434 (  25.191s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:10.499 (  25.256s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:10.530 (  25.287s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.000307339 (tol = 1e-05) r (rel) = 0.0031709(tol = 4e-05)
# 2023-09-02 10:44:10.566 (  25.322s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:10.602 (  25.359s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 5.7465e-09 (tol = 1e-05) r (rel) = 5.92881e-08(tol = 4e-05)
# 2023-09-02 10:44:10.602 (  25.359s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 26 linear solver iterations.
# 2023-09-02 10:44:10.657 (  25.413s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:10.722 (  25.479s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:10.754 (  25.510s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.000280215 (tol = 1e-05) r (rel) = 0.00302762(tol = 4e-05)
# 2023-09-02 10:44:10.788 (  25.545s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:10.826 (  25.583s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 5.04686e-09 (tol = 1e-05) r (rel) = 5.45295e-08(tol = 4e-05)
# 2023-09-02 10:44:10.826 (  25.583s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 27 linear solver iterations.
# 2023-09-02 10:44:10.882 (  25.639s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:10.947 (  25.704s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:10.978 (  25.735s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.000255243 (tol = 1e-05) r (rel) = 0.00288945(tol = 4e-05)
# 2023-09-02 10:44:11.012 (  25.769s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:11.050 (  25.807s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 4.4452e-09 (tol = 1e-05) r (rel) = 5.03214e-08(tol = 4e-05)
# 2023-09-02 10:44:11.050 (  25.807s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 27 linear solver iterations.
# 2023-09-02 10:44:11.106 (  25.863s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:11.172 (  25.929s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:11.203 (  25.959s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.000232283 (tol = 1e-05) r (rel) = 0.00275631(tol = 4e-05)
# 2023-09-02 10:44:11.237 (  25.994s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2023-09-02 10:44:11.275 (  26.032s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 3.92671e-09 (tol = 1e-05) r (rel) = 4.65949e-08(tol = 4e-05)
# 2023-09-02 10:44:11.275 (  26.032s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 27 linear solver iterations.
